# %% [markdown]
# <div><h1 align = 'center'><b>Data  Wrangling</b></h1></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
df = pd.read_csv('auto.csv')

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns = headers
df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
# 5          1               158         audi       gas        std         four
# 6          1                 ?         audi       gas        std         four
# 7          1               158         audi       gas      turbo         four
# 8          0                 ?         audi       gas      turbo          two
# 9          2               192          bmw       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
# 5        sedan          fwd           front       105.8  ...          136
# 6        wagon          fwd           front       105.8  ...          136
# 7        sedan          fwd           front       105.8  ...          131
# 8    hatchback          4wd           front        99.5  ...          131
# 9        sedan          rwd           front       101.2  ...          108
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  2.68    3.47               9.0        154      5000       19
# 2         mpfi  3.19    3.40              10.0        102      5500       24
# 3         mpfi  3.19    3.40               8.0        115      5500       18
# 4         mpfi  3.19    3.40               8.5        110      5500       19
# 5         mpfi  3.19    3.40               8.5        110      5500       19
# 6         mpfi  3.19    3.40               8.5        110      5500       19
# 7         mpfi  3.13    3.40               8.3        140      5500       17
# 8         mpfi  3.13    3.40               7.0        160      5500       16
# 9         mpfi  3.50    2.80               8.8        101      5800       23
#
#   highway-mpg  price
# 0          27  16500
# 1          26  16500
# 2          30  13950
# 3          22  17450
# 4          25  15250
# 5          25  17710
# 6          25  18920
# 7          20  23875
# 8          22      ?
# 9          29  16430
#
# [10 rows x 26 columns]

# %%
df.sample(10)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 121          1               154    plymouth       gas        std
# 80           3               153  mitsubishi       gas        std
# 142          0               102      subaru       gas        std
# 163          1               168      toyota       gas        std
# 25           1               148       dodge       gas        std
# 104          3               194      nissan       gas      turbo
# 85           1               125  mitsubishi       gas        std
# 51           1               104       mazda       gas        std
# 132          2               104        saab       gas        std
# 22           1               118       dodge       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 121         four      sedan          fwd           front        93.7  ...
# 80           two  hatchback          fwd           front        96.3  ...
# 142         four      sedan          fwd           front        97.2  ...
# 163          two  hatchback          rwd           front        94.5  ...
# 25          four      sedan          fwd           front        93.7  ...
# 104          two  hatchback          rwd           front        91.3  ...
# 85          four      sedan          fwd           front        96.3  ...
# 51           two  hatchback          fwd           front        93.1  ...
# 132         four      sedan          fwd           front        99.1  ...
# 22           two  hatchback          fwd           front        93.7  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 121           98         2bbl  2.97    3.23               9.4         68
# 80           122         2bbl  3.35    3.46               8.5         88
# 142          108         mpfi  3.62    2.64               9.0         94
# 163           98         2bbl  3.19    3.03               9.0         70
# 25            90         2bbl  2.97    3.23               9.4         68
# 104          181         mpfi  3.43    3.27               7.8        200
# 85           122         2bbl  3.35    3.46               8.5         88
# 51            91         2bbl  3.03    3.15               9.0         68
# 132          121         mpfi  3.54    3.07               9.3        110
# 22            98         mpfi  3.03    3.39               7.6        102
#
#      peak-rpm city-mpg highway-mpg  price
# 121      5500       31          38   7609
# 80       5000       25          32   8499
# 142      5200       26          32   9960
# 163      4800       29          34   8238
# 25       5500       31          38   7609
# 104      5200       17          23  19699
# 85       5000       25          32   8189
# 51       5000       31          38   6795
# 132      5250       21          28  12170
# 22       5500       24          30   7957
#
# [10 rows x 26 columns]

# %%
df.tail(10)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 194         -1                74  volvo       gas        std         four
# 195         -2               103  volvo       gas        std         four
# 196         -1                74  volvo       gas        std         four
# 197         -2               103  volvo       gas      turbo         four
# 198         -1                74  volvo       gas      turbo         four
# 199         -1                95  volvo       gas        std         four
# 200         -1                95  volvo       gas      turbo         four
# 201         -1                95  volvo       gas        std         four
# 202         -1                95  volvo    diesel      turbo         four
# 203         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 194      wagon          rwd           front       104.3  ...          141
# 195      sedan          rwd           front       104.3  ...          141
# 196      wagon          rwd           front       104.3  ...          141
# 197      sedan          rwd           front       104.3  ...          130
# 198      wagon          rwd           front       104.3  ...          130
# 199      sedan          rwd           front       109.1  ...          141
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          173
# 202      sedan          rwd           front       109.1  ...          145
# 203      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 194         mpfi  3.78    3.15               9.5        114      5400
# 195         mpfi  3.78    3.15               9.5        114      5400
# 196         mpfi  3.78    3.15               9.5        114      5400
# 197         mpfi  3.62    3.15               7.5        162      5100
# 198         mpfi  3.62    3.15               7.5        162      5100
# 199         mpfi  3.78    3.15               9.5        114      5400
# 200         mpfi  3.78    3.15               8.7        160      5300
# 201         mpfi  3.58    2.87               8.8        134      5500
# 202          idi  3.01    3.40              23.0        106      4800
# 203         mpfi  3.78    3.15               9.5        114      5400
#
#     city-mpg highway-mpg  price
# 194       23          28  13415
# 195       24          28  15985
# 196       24          28  16515
# 197       17          22  18420
# 198       17          22  18950
# 199       23          28  16845
# 200       19          25  19045
# 201       18          23  21485
# 202       26          27  22470
# 203       19          25  22625
#
# [10 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          1               NaN  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               NaN         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  2.68    3.47               9.0        154      5000       19
# 2         mpfi  3.19    3.40              10.0        102      5500       24
# 3         mpfi  3.19    3.40               8.0        115      5500       18
# 4         mpfi  3.19    3.40               8.5        110      5500       19
#
#   highway-mpg  price
# 0          27  16500
# 1          26  16500
# 2          30  13950
# 3          22  17450
# 4          25  15250
#
# [5 rows x 26 columns]

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False               True  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
#    fuel-system   bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0        False  False   False              False       False     False
# 1        False  False   False              False       False     False
# 2        False  False   False              False       False     False
# 3        False  False   False              False       False     False
# 4        False  False   False              False       False     False
#
#    city-mpg  highway-mpg  price
# 0     False        False  False
# 1     False        False  False
# 2     False        False  False
# 3     False        False  False
# 4     False        False  False
#
# [5 rows x 26 columns]

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# symboling
# symboling
# False    204
# Name: count, dtype: int64
#
# normalized-losses
# normalized-losses
# False    164
# True      40
# Name: count, dtype: int64
#
# make
# make
# False    204
# Name: count, dtype: int64
#
# fuel-type
# fuel-type
# False    204
# Name: count, dtype: int64
#
# aspiration
# aspiration
# False    204
# Name: count, dtype: int64
#
# num-of-doors
# num-of-doors
# False    202
# True       2
# Name: count, dtype: int64
#
# body-style
# body-style
# False    204
# Name: count, dtype: int64
#
# drive-wheels
# drive-wheels
# False    204
# Name: count, dtype: int64
#
# engine-location
# engine-location
# False    204
# Name: count, dtype: int64
#
# wheel-base
# wheel-base
# False    204
# Name: count, dtype: int64
#
# length
# length
# False    204
# Name: count, dtype: int64
#
# width
# width
# False    204
# Name: count, dtype: int64
#
# height
# height
# False    204
# Name: count, dtype: int64
#
# curb-weight
# curb-weight
# False    204
# Name: count, dtype: int64
#
# engine-type
# engine-type
# False    204
# Name: count, dtype: int64
#
# num-of-cylinders
# num-of-cylinders
# False    204
# Name: count, dtype: int64
#
# engine-size
# engine-size
# False    204
# Name: count, dtype: int64
#
# fuel-system
# fuel-system
# False    204
# Name: count, dtype: int64
#
# bore
# bore
# False    200
# True       4
# Name: count, dtype: int64
#
# stroke
# stroke
# False    200
# True       4
# Name: count, dtype: int64
#
# compression-ratio
# compression-ratio
# False    204
# Name: count, dtype: int64
#
# horsepower
# horsepower
# False    202
# True       2
# Name: count, dtype: int64
#
# peak-rpm
# peak-rpm
# False    202
# True       2
# Name: count, dtype: int64
#
# city-mpg
# city-mpg
# False    204
# Name: count, dtype: int64
#
# highway-mpg
# highway-mpg
# False    204
# Name: count, dtype: int64
#
# price
# price
# False    200
# True       4
# Name: count, dtype: int64

# %% [markdown]
# <h4>Calculate the mean value for the "normalized-losses" column </h4>

# %%
avg_norm_loss = df["normalized-losses"].astype("float").mean(axis=0)
print("Average of normalized-losses:", avg_norm_loss)
# Out:
# Average of normalized-losses: 122.0

# %% [markdown]
# <h4>Replace "NaN" with mean value in "normalized-losses" column</h4>

# %%
df["normalized-losses"].replace(np.nan, avg_norm_loss)
# Out:
# 0      122.0
# 1      122.0
# 2        164
# 3        164
# 4      122.0
#        ...
# 199       95
# 200       95
# 201       95
# 202       95
# 203       95
# Name: normalized-losses, Length: 204, dtype: object

# %% [markdown]
# <h4>Calculate the mean value for the "bore" column</h4>

# %%
avg_bore=df['bore'].astype('float').mean(axis=0)
print("Average of bore:", avg_bore)
# Out:
# Average of bore: 3.3290499999999996

# %% [markdown]
# <h4>Replace "NaN" with the mean value in the "bore" column</h4>

# %%
df["bore"].replace(np.nan, avg_bore)
# Out:
# 0      3.47
# 1      2.68
# 2      3.19
# 3      3.19
# 4      3.19
#        ...
# 199    3.78
# 200    3.78
# 201    3.58
# 202    3.01
# 203    3.78
# Name: bore, Length: 204, dtype: object

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Part  #1: </h1>
#
# </div>

# %%
avg_stroke = df['stroke'].astype('float').mean(axis = 0)

df['stroke'].replace(np.nan, avg_stroke)
# Out:
# 0      2.68
# 1      3.47
# 2      3.40
# 3      3.40
# 4      3.40
#        ...
# 199    3.15
# 200    3.15
# 201    2.87
# 202    3.40
# 203    3.15
# Name: stroke, Length: 204, dtype: object

# %% [markdown]
# <h4>Calculate the mean value for the "horsepower" column</h4>

# %%
avg_horsepower = df['horsepower'].astype('float').mean(axis=0)
print("Average horsepower:", avg_horsepower)
# Out:
# Average horsepower: 104.22277227722772

# %% [markdown]
# <h4>Replace "NaN" with the mean value in the "horsepower" column</h4>

# %%
df['horsepower'].replace(np.nan, avg_horsepower)
# Out:
# 0      111
# 1      154
# 2      102
# 3      115
# 4      110
#       ...
# 199    114
# 200    160
# 201    134
# 202    106
# 203    114
# Name: horsepower, Length: 204, dtype: object

# %% [markdown]
# <h4>Calculate the mean value for "peak-rpm" column</h4>

# %%
avg_peakrpm=df['peak-rpm'].astype('float').mean(axis=0)
print("Average peak rpm:", avg_peakrpm)
# Out:
# Average peak rpm: 5125.990099009901

# %% [markdown]
# <h4>Replace "NaN" with the mean value in the "peak-rpm" column</h4>

# %%
df['peak-rpm'].replace(np.nan, avg_peakrpm)
# Out:
# 0      5000
# 1      5000
# 2      5500
# 3      5500
# 4      5500
#        ...
# 199    5400
# 200    5300
# 201    5500
# 202    4800
# 203    5400
# Name: peak-rpm, Length: 204, dtype: object

# %%
df['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    114
# two      88
# Name: count, dtype: int64

# %% [markdown]
# We can see that four doors are the most common type. We can also use the ".idxmax()" method to calculate the most common type automatically:

# %%
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %% [markdown]
# The replacement procedure is very similar to what we have seen previously

# %%
df["num-of-doors"].replace(np.nan, "four")
# Out:
# 0       two
# 1       two
# 2      four
# 3      four
# 4       two
#        ...
# 199    four
# 200    four
# 201    four
# 202    four
# 203    four
# Name: num-of-doors, Length: 204, dtype: object

# %% [markdown]
# Finally, let's drop all rows that do not have price data:

# %%
df.dropna(subset=["price"], axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          1               NaN  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               NaN         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  2.68    3.47               9.0        154      5000       19
# 2         mpfi  3.19    3.40              10.0        102      5500       24
# 3         mpfi  3.19    3.40               8.0        115      5500       18
# 4         mpfi  3.19    3.40               8.5        110      5500       19
#
#   highway-mpg  price
# 0          27  16500
# 1          26  16500
# 2          30  13950
# 3          22  17450
# 4          25  15250
#
# [5 rows x 26 columns]

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# <h4>Convert data types to proper format</h4>

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df = df.dropna(subset=["normalized-losses"])
df["normalized-losses"] = df["normalized-losses"].astype("int")

df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# Convert mpg to L/100km by mathematical operation (235 divided by mpg)
df['city-L/100km'] = 235/df["city-mpg"]

# check your transformed data 
df.head()
# Out:
#    symboling  normalized-losses  make fuel-type aspiration num-of-doors  \
# 2          2                164  audi       gas        std         four
# 3          2                164  audi       gas        std         four
# 5          1                158  audi       gas        std         four
# 7          1                158  audi       gas      turbo         four
# 8          2                192   bmw       gas        std          two
#
#   body-style drive-wheels engine-location  wheel-base  ...  fuel-system  bore  \
# 2      sedan          fwd           front        99.8  ...         mpfi  3.19
# 3      sedan          4wd           front        99.4  ...         mpfi  3.19
# 5      sedan          fwd           front       105.8  ...         mpfi  3.19
# 7      sedan          fwd           front       105.8  ...         mpfi  3.13
# 8      sedan          rwd           front       101.2  ...         mpfi  3.50
#
#    stroke  compression-ratio horsepower peak-rpm  city-mpg highway-mpg  \
# 2     3.4               10.0        102   5500.0        24          30
# 3     3.4                8.0        115   5500.0        18          22
# 5     3.4                8.5        110   5500.0        19          25
# 7     3.4                8.3        140   5500.0        17          20
# 8     2.8                8.8        101   5800.0        23          29
#
#      price  city-L/100km
# 2  13950.0      9.791667
# 3  17450.0     13.055556
# 5  17710.0     12.368421
# 7  23875.0     13.823529
# 8  16430.0     10.217391
#
# [5 rows x 27 columns]

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Part  #2: </h1>
#
# </div>

# %% [markdown]
# According to the example above, transform mpg to L/100km in the column of "highway-mpg" and change the name of column to "highway-L/100km".

# %%
df['highway-L/100km'] = 235/df['highway-mpg']

df.head(10)
# Out:
#     symboling  normalized-losses       make fuel-type aspiration num-of-doors  \
# 2           2                164       audi       gas        std         four
# 3           2                164       audi       gas        std         four
# 5           1                158       audi       gas        std         four
# 7           1                158       audi       gas      turbo         four
# 8           2                192        bmw       gas        std          two
# 9           0                192        bmw       gas        std         four
# 10          0                188        bmw       gas        std          two
# 11          0                188        bmw       gas        std         four
# 16          2                121  chevrolet       gas        std          two
# 17          1                 98  chevrolet       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  bore  stroke  \
# 2       sedan          fwd           front        99.8  ...  3.19    3.40
# 3       sedan          4wd           front        99.4  ...  3.19    3.40
# 5       sedan          fwd           front       105.8  ...  3.19    3.40
# 7       sedan          fwd           front       105.8  ...  3.13    3.40
# 8       sedan          rwd           front       101.2  ...  3.50    2.80
# 9       sedan          rwd           front       101.2  ...  3.50    2.80
# 10      sedan          rwd           front       101.2  ...  3.31    3.19
# 11      sedan          rwd           front       101.2  ...  3.31    3.19
# 16  hatchback          fwd           front        88.4  ...  2.91    3.03
# 17  hatchback          fwd           front        94.5  ...  3.03    3.11
#
#     compression-ratio  horsepower peak-rpm city-mpg  highway-mpg    price  \
# 2                10.0         102   5500.0       24           30  13950.0
# 3                 8.0         115   5500.0       18           22  17450.0
# 5                 8.5         110   5500.0       19           25  17710.0
# 7                 8.3         140   5500.0       17           20  23875.0
# 8                 8.8         101   5800.0       23           29  16430.0
# 9                 8.8         101   5800.0       23           29  16925.0
# 10                9.0         121   4250.0       21           28  20970.0
# 11                9.0         121   4250.0       21           28  21105.0
# 16                9.5          48   5100.0       47           53   5151.0
# 17                9.6          70   5400.0       38           43   6295.0
#
#     city-L/100km  highway-L/100km
# 2       9.791667         7.833333
# 3      13.055556        10.681818
# 5      12.368421         9.400000
# 7      13.823529        11.750000
# 8      10.217391         8.103448
# 9      10.217391         8.103448
# 10     11.190476         8.392857
# 11     11.190476         8.392857
# 16      5.000000         4.433962
# 17      6.184211         5.465116
#
# [10 rows x 28 columns]

# %%
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Part  #3: </h1>
#
# </div>

# %% [markdown]
# According to the example above, normalize the column "height".

# %%
df['height'] = df['height']/df['height'].max()

df[["length","width","height"]].head()
# Out:
#      length     width    height
# 2  0.871668  0.923291  0.908027
# 3  0.871668  0.926081  0.908027
# 5  0.951135  0.995816  0.931438
# 7  0.951135  0.995816  0.934783
# 8  0.872655  0.903766  0.908027

# %% [markdown]
# Convert data to correct format:

# %%
df["horsepower"]=df["horsepower"].astype(int, copy=True)

# %% [markdown]
# Let's plot the histogram of horsepower to see what the distribution of horsepower looks like.

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([ 48.        ,  98.66666667, 149.33333333, 200.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %% [markdown]
# We apply the function "cut" to determine what each value of df['horsepower'] belongs to.

# %%
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 2          102            Medium
# 3          115            Medium
# 5          110            Medium
# 7          140            Medium
# 8          101            Medium
# 9          101            Medium
# 10         121            Medium
# 11         121            Medium
# 16          48               Low
# 17          70               Low
# 18          70               Low
# 19          68               Low
# 20          68               Low
# 21         102            Medium
# 22          68               Low
# 23          68               Low
# 24          68               Low
# 25         102            Medium
# 26          88               Low
# 27         145            Medium

# %% [markdown]
# Let's see the number of vehicles in each bin:

# %%
df["horsepower-binned"].value_counts()
# Out:
# horsepower-binned
# Low       96
# Medium    52
# High      16
# Name: count, dtype: int64

# %%
pyplot.bar(group_names, df["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
# draw historgram of attribute "horsepower" with bins = 3
plt.pyplot.hist(df["horsepower"], bins = 3)

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'city-L/100km', 'highway-L/100km',
#        'horsepower-binned'],
#       dtype='object')

# %% [markdown]
# Get the indicator variables and assign it to data frame "dummy_variable_1":

# %%
dummy_variable_1 = pd.get_dummies(df["fuel-type"])
dummy_variable_1.head()
# Out:
#    diesel   gas
# 2   False  True
# 3   False  True
# 5   False  True
# 7   False  True
# 8   False  True

# %%
#Change the column names for clarity:
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 2             False           True
# 3             False           True
# 5             False           True
# 7             False           True
# 8             False           True

# %% [markdown]
# In the dataframe, column 'fuel-type' has values for 'gas' and 'diesel' as 0s and 1s now.

# %%
# merge data frame "df" and "dummy_variable_1" 
df = pd.concat([df, dummy_variable_1], axis=1)

# drop original column "fuel-type" from "df"
df.drop("fuel-type", axis = 1, inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses  make aspiration num-of-doors body-style  \
# 2          2                164  audi        std         four      sedan
# 3          2                164  audi        std         four      sedan
# 5          1                158  audi        std         four      sedan
# 7          1                158  audi      turbo         four      sedan
# 8          2                192   bmw        std          two      sedan
#
#   drive-wheels engine-location  wheel-base    length  ...  horsepower  \
# 2          fwd           front        99.8  0.871668  ...         102
# 3          4wd           front        99.4  0.871668  ...         115
# 5          fwd           front       105.8  0.951135  ...         110
# 7          fwd           front       105.8  0.951135  ...         140
# 8          rwd           front       101.2  0.872655  ...         101
#
#    peak-rpm  city-mpg highway-mpg    price  city-L/100km highway-L/100km  \
# 2    5500.0        24          30  13950.0      9.791667        7.833333
# 3    5500.0        18          22  17450.0     13.055556       10.681818
# 5    5500.0        19          25  17710.0     12.368421        9.400000
# 7    5500.0        17          20  23875.0     13.823529       11.750000
# 8    5800.0        23          29  16430.0     10.217391        8.103448
#
#    horsepower-binned  fuel-type-diesel  fuel-type-gas
# 2             Medium             False           True
# 3             Medium             False           True
# 5             Medium             False           True
# 7             Medium             False           True
# 8             Medium             False           True
#
# [5 rows x 30 columns]

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Part  #4: </h1>
#
# </div>

# %% [markdown]
# Similar to before, create an indicator variable for the column "aspiration"

# %%
dummy_variabletwo = pd.get_dummies(df['aspiration'])
dummy_variabletwo.rename(columns={'std':'aspiration-std', 'turbo': 'aspiration-turbo'}, inplace=True)
dummy_variabletwo.head(10)
# Out:
#     aspiration-std  aspiration-turbo
# 2             True             False
# 3             True             False
# 5             True             False
# 7            False              True
# 8             True             False
# 9             True             False
# 10            True             False
# 11            True             False
# 16            True             False
# 17            True             False

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Part  #5: </h1>
#
# </div>

# %% [markdown]
# Merge the new dataframe to the original dataframe, then drop the column 'aspiration'.

# %%
df = pd.concat([df, dummy_variabletwo], axis=1)
df.drop('aspiration', axis = 1, inplace=True)
df.head(10)
# Out:
#     symboling  normalized-losses       make num-of-doors body-style  \
# 2           2                164       audi         four      sedan
# 3           2                164       audi         four      sedan
# 5           1                158       audi         four      sedan
# 7           1                158       audi         four      sedan
# 8           2                192        bmw          two      sedan
# 9           0                192        bmw         four      sedan
# 10          0                188        bmw          two      sedan
# 11          0                188        bmw         four      sedan
# 16          2                121  chevrolet          two  hatchback
# 17          1                 98  chevrolet          two  hatchback
#
#    drive-wheels engine-location  wheel-base    length     width  ...  \
# 2           fwd           front        99.8  0.871668  0.923291  ...
# 3           4wd           front        99.4  0.871668  0.926081  ...
# 5           fwd           front       105.8  0.951135  0.995816  ...
# 7           fwd           front       105.8  0.951135  0.995816  ...
# 8           rwd           front       101.2  0.872655  0.903766  ...
# 9           rwd           front       101.2  0.872655  0.903766  ...
# 10          rwd           front       101.2  0.872655  0.903766  ...
# 11          rwd           front       101.2  0.872655  0.903766  ...
# 16          fwd           front        88.4  0.696446  0.841004  ...
# 17          fwd           front        94.5  0.769497  0.887029  ...
#
#     city-mpg  highway-mpg    price city-L/100km  highway-L/100km  \
# 2         24           30  13950.0     9.791667         7.833333
# 3         18           22  17450.0    13.055556        10.681818
# 5         19           25  17710.0    12.368421         9.400000
# 7         17           20  23875.0    13.823529        11.750000
# 8         23           29  16430.0    10.217391         8.103448
# 9         23           29  16925.0    10.217391         8.103448
# 10        21           28  20970.0    11.190476         8.392857
# 11        21           28  21105.0    11.190476         8.392857
# 16        47           53   5151.0     5.000000         4.433962
# 17        38           43   6295.0     6.184211         5.465116
#
#    horsepower-binned  fuel-type-diesel  fuel-type-gas  aspiration-std  \
# 2             Medium             False           True            True
# 3             Medium             False           True            True
# 5             Medium             False           True            True
# 7             Medium             False           True           False
# 8             Medium             False           True            True
# 9             Medium             False           True            True
# 10            Medium             False           True            True
# 11            Medium             False           True            True
# 16               Low             False           True            True
# 17               Low             False           True            True
#
#     aspiration-turbo
# 2              False
# 3              False
# 5              False
# 7               True
# 8              False
# 9              False
# 10             False
# 11             False
# 16             False
# 17             False
#
# [10 rows x 31 columns]

# %%
#save the file
df.to_csv('clean_df.csv')

# %% [markdown]
# <h1 align = 'center'>Thank You</h1>
